# %%
import numpy as np
import json

k3 = np.load('./output/CST-matched_scvae-latent-batch/version_5/inference.npz')
k0 = np.load('./output/CST-matched_scvae-latent-batch/version_6/inference.npz')
val_indices = json.load(open('./output/CST-matched_scvae-latent-batch/version_5/dataset_meta.json'))['val_data_indices']

# %%
T = k3['T']
print(T.shape)
# Out:
# (584, 516)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")
sns.set_context("paper")

# %%
def vis(label, T, y, gt_T, gt):
    plt.plot(T, y, label=label)
    plt.scatter(T[gt_T], gt, c='red')

# %%
def compare(cell, gene, fn=None):
    print(f'Cell {val_indices[cell]} Gene {gene}')
    vis('CST', k3['T'][cell], k3['y'][cell, :, gene], k3['gt_T'][cell], k3['gt'][cell, :, gene])
    vis('Transformer', k0['T'][cell], k0['y'][cell, :, gene], k0['gt_T'][cell], k0['gt'][cell, :, gene])
    plt.legend()
    if fn is not None:
        plt.savefig(fn)
    plt.show()

# %%
compare(0, 10, fn=f'imgs/wonoise/C_{val_indices[0]}_G_{10}')
# Out:
# Cell 4 Gene 10

# %%
compare(400, 10, fn=f'imgs/wonoise/C_{val_indices[400]}_G_{10}')
# Out:
# Cell 1391 Gene 10

# %%
compare(0, 60, fn=f'imgs/wonoise/C_{val_indices[0]}_G_{60}')
# Out:
# Cell 4 Gene 60

# %%
compare(400, 60, fn=f'imgs/wonoise/C_{val_indices[400]}_G_{60}')
# Out:
# Cell 1391 Gene 60
